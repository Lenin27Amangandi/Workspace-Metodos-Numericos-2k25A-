# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(-1, 8, 400)

x2_1 = 7 - x1
x2_2 = (2 * x1) / 5

plt.figure(figsize=(8, 6))

plt.plot(x1, x2_1, label='$x_1 + x_2 = 7$', color='b')
plt.plot(x1, x2_2, label='-$2x_1 + 5x_2 = 0$', color='r')

plt.scatter([0, 5], [7, 2], color='black', zorder=5)

plt.title('Gráfica de las ecuaciones')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')

plt.legend()

plt.grid(True)
plt.axhline(0, color='black',linewidth=1)
plt.axvline(0, color='black',linewidth=1)
plt.show()

# %% [markdown]
# ## 1) Modificar el codigo y obtener

# %%
# %load_ext autoreload
# %autoreload 2
from src import eliminacion_gaussiana, gauss_jacobi, gauss_seidel
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
A = [[1, 1],[-2, 5]]

b = [7, 0]
n=2
gauss_jacobi(A=A, b=b, x=[0]*n, tol=1e-5, max_iter=10)
# Out:
# [01-20 17:43:36][INFO][User] i= 0 x: [[0. 0.]]
# [01-20 17:43:36][INFO][User] i= 1 x: [[7. 0.]]
# [01-20 17:43:36][INFO][User] i= 2 x: [[7.  2.8]]
# [01-20 17:43:36][INFO][User] i= 3 x: [[4.2 2.8]]
# [01-20 17:43:36][INFO][User] i= 4 x: [[4.2  1.68]]
# [01-20 17:43:36][INFO][User] i= 5 x: [[5.32 1.68]]
# [01-20 17:43:36][INFO][User] i= 6 x: [[5.32  2.128]]
# [01-20 17:43:36][INFO][User] i= 7 x: [[4.872 2.128]]
# [01-20 17:43:36][INFO][User] i= 8 x: [[4.872  1.9488]]
# [01-20 17:43:36][INFO][User] i= 9 x: [[5.0512 1.9488]]
# [01-20 17:43:36][INFO][User] i= 10 x: [[5.0512  2.02048]]
# array([[5.0512 ],
#        [2.02048]])

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(-1, 8, 400)
x2_1 = 7 - x1
x2_2 = (2 * x1) / 5

A = [[1, 1], [-2, 5]]
b = [7, 3]
n = 2

iterations = gauss_jacobi(A=A, b=b, x=[0]*n, tol=1e-5, max_iter=10)

plt.figure(figsize=(8, 6))

plt.plot(x1, x2_1, label='$x_1 + x_2 = 7$', color='b')
plt.plot(x1, x2_2, label='-$2x_1 + 5x_2 = 0$', color='r')

plt.scatter([0, 5], [7, 2], color='black', zorder=5)

for i, iteration in enumerate(iterations):
    plt.scatter(iteration[0], iteration[1], color='g', zorder=10)
    plt.text(iteration[0], iteration[1], f'Iter {i+1}', fontsize=9, color='g')

plt.title('Gráfica de las ecuaciones y las iteraciones de Jacobi')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')

plt.legend()
plt.grid(True)
plt.axhline(0, color='black',linewidth=1)
plt.axvline(0, color='black',linewidth=1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(-1, 8, 400)
x2_1 = 7 - x1
x2_2 = (2 * x1) / 5

A = [[1, 1], [-2, 5]]
b = [7, 0]
n = 2

iterations = gauss_jacobi(A=A, b=b, x=[0]*n, tol=1e-5, max_iter=10)

plt.figure(figsize=(8, 6))

plt.plot(x1, x2_1, label='$x_1 + x_2 = 7$', color='b')
plt.plot(x1, x2_2, label='-$2x_1 + 5x_2 = 0$', color='r')

plt.scatter([0, 5], [7, 2], color='black', zorder=5)

x_values = []
y_values = []

for i, iteration in enumerate(iterations):
    x_values.append(iteration[0][0])
    y_values.append(iteration[1][0])
    plt.scatter(iteration[0], iteration[1], color='g', zorder=10)
    plt.text(iteration[0], iteration[1], f'Iter {i+1}', fontsize=9, color='g')

plt.plot(x_values, y_values, color='g', linestyle='-', linewidth=1)

plt.title('Gráfica de las ecuaciones y las iteraciones de Jacobi')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')

plt.legend()
plt.grid(True)
plt.axhline(0, color='black',linewidth=1)
plt.axvline(0, color='black',linewidth=1)

plt.show()
