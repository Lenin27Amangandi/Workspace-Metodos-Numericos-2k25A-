# %% [markdown]
# # Escuela Politecnica Nacional
# ## Metodos Numericos
#
# Nombre: Lenin Amangandi
#
# Tema: Series de Taylor y polinomios de Lagrange

# %% [markdown]
# ## 1. Grafique las curvas de las series de Taylor de varios órdenes para los siguientes casos:

# %% [markdown]
# ### Caso 1: cos(x) alrededor de $$x_0 = 0$$, n=4
# - **Orden 0:** $$P_0(x) = 1$$
# - **Orden 1:** $$P_1(x) = 1$$
# - **Orden 2:** $$P_2(x) = 1 - \frac{x^2}{2}$$
# - **Orden 3:** $$P_3(x) = 1 - \frac{x^2}{2}$$
# - **Orden 4:** $$P_4(x) = 1 - \frac{x^2}{2} + \frac{x^4}{24}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

x_min = -10
x_max = 10  
y_min = -2
y_max = 2
num_puntos = 500

def f_cos(x):
    return np.cos(x)

def P0(x):
    return np.ones_like(x)

def P1(x):
    return np.ones_like(x)

def P2(x):
    return 1 - (x**2)/2

def P3(x):
    return 1 - (x**2)/2

def P4(x):
    return 1 - (x**2)/2 + (x**4)/24


x = np.linspace(x_min, x_max, num_puntos)

plt.figure(figsize=(10, 6))
plt.plot(x, f_cos(x), 'k', label='cos(x)', linewidth=2)
plt.plot(x, P0(x), '--', label='P0(x)')
plt.plot(x, P2(x), '--', label='P2(x)')
plt.plot(x, P4(x), '--', label='P4(x)')

plt.title("Aproximaciones de Taylor de cos(x) alrededor de x₀=0", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.grid(True, linestyle=':')
plt.legend()
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ### Caso 2: $$\frac{1}{1-x}$$ alrededor de $$x_0 = 0$$, n=3
#
# - Orden 0: $$P_0(x) = 1$$
# - Orden 1: $$P_1(x) = 1 + x$$
# - Orden 2: $$P_2(x) = 1 + x + x^2$$
# - Orden 3: $$P_3(x) = 1 + x + x^2 + x^3$$

# %%
import numpy as np
import matplotlib.pyplot as plt

x_min = -1.8
x_max = 0.99
y_min = -5
y_max = 5
num_puntos = 600

def f_racional(x):
    return 1 / (1 - x)

def P0(x):
    return np.ones_like(x)

def P1(x):
    return 1 + x

def P2(x):
    return 1 + x + x**2

def P3(x):
    return 1 + x + x**2 + x**3

x = np.linspace(x_min, x_max, num_puntos)

plt.figure(figsize=(10, 6))
plt.plot(x, f_racional(x), 'k', label='1 / (1 - x)', linewidth=2)
plt.plot(x, P0(x), '--', label='P0(x)')
plt.plot(x, P1(x), '--', label='P1(x)')
plt.plot(x, P2(x), '--', label='P2(x)')
plt.plot(x, P3(x), '--', label='P3(x)')

plt.title("Aproximaciones de Taylor de 1/(1 - x) alrededor de x₀=0", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.grid(True, linestyle=':')
plt.legend()
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ### Caso 3: ln(x) alrededor de x_0 = 1, n=3
#
# - Orden 0: $$P_0(x) = ln(1)$$
# - Orden 1: $$P_1(x) = (x-1)$$
# - Orden 2: $$P_2(x) = (x-1) - \frac{(x-1)^2}{2}$$
# - Orden 3: $$P_3(x) = (x-1) - \frac{(x-1)^2}{2} + \frac{(x-1)^3}{3}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

x_min = 0.1
x_max = 3.2
y_min = -3
y_max = 2
num_puntos = 500

def f_ln(x):
    return np.log(x)

def P0(x):
    return np.zeros_like(x)

def P1(x):
    return (x - 1)

def P2(x):
    return (x - 1) - ((x - 1)**2)/2

def P3(x):
    return (x - 1) - ((x - 1)**2)/2 + ((x - 1)**3)/3

x = np.linspace(x_min, x_max, num_puntos)

plt.figure(figsize=(10, 6))
plt.plot(x, f_ln(x), 'k', label='ln(x)', linewidth=2)
plt.plot(x, P0(x), '--', label='P0(x)')
plt.plot(x, P1(x), '--', label='P1(x)')
plt.plot(x, P2(x), '--', label='P2(x)')
plt.plot(x, P3(x), '--', label='P3(x)')

plt.title("Aproximaciones de Taylor de ln(x) alrededor de x₀=1", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.grid(True, linestyle=':')
plt.legend()
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ### Caso 3.1: ln(x) alrededor de x_0 = 10, n=3
#
# - Orden 0: $$P_0(x) = ln(10) $$
# - Orden 1: $$P_1(x) = ln(10) + \frac{(x-10)}{10}$$
# - Orden 2: $$P_2(x) = ln(10) + \frac{(x-10)}{10} - \frac{(x-10)^2}{2 \cdot 10^2}$$
# - Orden 3: $$P_3(x) = ln(10) + \frac{(x-10)}{10} - \frac{(x-10)^2}{2 \cdot 10^2} + \frac{(x-10)^3}{3 \cdot 10^3}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

x_min = 2
x_max = 18
y_min = 1
y_max = 3
num_puntos = 600

def f_ln(x):
    return np.log(x)

def P0(x):
    return np.log(10) * np.ones_like(x)

def P1(x):
    return np.log(10) + (x - 10)/10

def P2(x):
    return np.log(10) + (x - 10)/10 - ((x - 10)**2) / (2 * 10**2)

def P3(x):
    return np.log(10) + (x - 10)/10 - ((x - 10)**2) / (2 * 10**2) + ((x - 10)**3) / (3 * 10**3)

x = np.linspace(x_min, x_max, num_puntos)

plt.figure(figsize=(10, 6))
plt.plot(x, f_ln(x), 'k', label='ln(x)', linewidth=2)
plt.plot(x, P0(x), '--', label='P0(x)')
plt.plot(x, P1(x), '--', label='P1(x)')
plt.plot(x, P2(x), '--', label='P2(x)')
plt.plot(x, P3(x), '--', label='P3(x)')

plt.title("Aproximaciones de Taylor de ln(x) alrededor de x₀=10", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.grid(True, linestyle=':')
plt.legend()
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.show()
